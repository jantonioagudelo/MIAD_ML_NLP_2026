# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Redes Neuronales
#
# En este notebook aprenderá a construir y a entrenar redes neuronales de una capa y multicapas, usando la librería [Keras](https://keras.io/).
#
# Este notebook tiene una licencia de [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US). Un agradecimiento especial para [Valerio Maggio](https://mpba.fbk.eu).

# %% [markdown]
# ## Instrucciones Generales
#
# Keras es una librería de redes neuronales altamente modular, escrita en Python y capaz de ejecutarse sobre TensorFlow o Theano. Fue desarrollada con el objetivo de permitir una experimentación rápida con modelos de redes neuronales.
#
# Este notebook esta compuesto por dos secciones. En la primera sección, usted beberá construir y entrenar una red neuronal de una capa para predecir el precio de una casa con el set de datos Boston Housing Data. En la segunda parte, se usará el mismo dataset pero usted beberá construir y entrenar una red neuronal multicapa para identificar sus ventajas. Para conocer más detalles de la base, puede ingresar al siguiente [vínculo](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/).
#
# Para realizar la actividad, solo siga las indicaciones asociadas a cada celda del notebook.

# %% [markdown]
# ## Importar base de datos y librerías

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import fetch_california_housing
# Carga de datos de la librería sklearn
california_housing = fetch_california_housing()
dataset = pd.DataFrame(california_housing.data, columns=california_housing.feature_names)
dataset['PRICE'] = california_housing.target

dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  PRICE
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
# ## Definición de variables predictoras  y de interés

# %%
# Definición de variables predictoras (X)
X = dataset.drop('PRICE', axis=1)

# Definición de variable de interés (y)
Y = pd.DataFrame(california_housing.target, columns=['labels'])

# %%
Y
# Out:
#        labels
# 0       4.526
# 1       3.585
# 2       3.521
# 3       3.413
# 4       3.422
# ...       ...
# 20635   0.781
# 20636   0.771
# 20637   0.923
# 20638   0.847
# 20639   0.894
#
# [20640 rows x 1 columns]

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
X_train, X_test , Y_train, Y_test = train_test_split(X,Y, test_size=0.3 ,random_state=22)

# %%
# Normalización de variables predictoras (X) con la función StandardScaler
from sklearn.preprocessing import StandardScaler

# Definición de la función StandardScaler
scaler = StandardScaler()
scaler.fit(X)

# Transformación de los set de entrenamiento y test
X_train = pd.DataFrame(data=scaler.transform(X_train), columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=X_test.columns, index=X_test.index)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
# Definición de dimensiones de salida, varaibles de interés
output_var = Y_train.shape[1]
print(output_var, ' output variables')
# Out:
# 1  output variables

# %%
# Definición de dimensiones de entrada, varaibles predictoras
dims = X_train.shape[1]
print(dims, 'input variables')
# Out:
# 8 input variables

# %% [markdown]
# # Red neuronal de una sola capa

# %%
# Importación librerías
# !pip install livelossplot

from keras.models import Sequential
from keras.layers import Dense, Activation
from livelossplot import PlotLossesKeras
from keras import backend as K
import keras.optimizers as opts
# Out:
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: livelossplot in C:\Users\janto\AppData\Roaming\Python\Python311\site-packages (0.6.1)
# Requirement already satisfied: bokeh>=3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from livelossplot) (3.3.4)
# Requirement already satisfied: ipython>=8.0 in C:\ProgramData\anaconda3\Lib\site-packages (from livelossplot) (8.20.0)
# Requirement already satisfied: matplotlib>=3.6 in C:\ProgramData\anaconda3\Lib\site-packages (from livelossplot) (3.8.0)
# Requirement already satisfied: Jinja2>=2.9 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (3.1.3)
# Requirement already satisfied: contourpy>=1 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (25.0)
# Requirement already satisfied: pandas>=1.2 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in C:\ProgramData\anaconda3\Lib\site-packages (from bokeh>=3.0->livelossplot) (2022.9.0)
# Requirement already satisfied: decorator in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (0.18.1)
# Requirement already satisfied: matplotlib-inline in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (2.15.1)
# Requirement already satisfied: stack-data in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (0.2.0)
# Requirement already satisfied: traitlets>=5 in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (5.14.3)
# Requirement already satisfied: colorama in C:\ProgramData\anaconda3\Lib\site-packages (from ipython>=8.0->livelossplot) (0.4.6)
# Requirement already satisfied: wcwidth in C:\ProgramData\anaconda3\Lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=8.0->livelossplot) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in C:\ProgramData\anaconda3\Lib\site-packages (from jedi>=0.16->ipython>=8.0->livelossplot) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from Jinja2>=2.9->bokeh>=3.0->livelossplot) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.6->livelossplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.6->livelossplot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.6->livelossplot) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.6->livelossplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in C:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.6->livelossplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas>=1.2->bokeh>=3.0->livelossplot) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in C:\ProgramData\anaconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->livelossplot) (1.16.0)
# Requirement already satisfied: executing in C:\ProgramData\anaconda3\Lib\site-packages (from stack-data->ipython>=8.0->livelossplot) (0.8.3)
# Requirement already satisfied: asttokens in C:\ProgramData\anaconda3\Lib\site-packages (from stack-data->ipython>=8.0->livelossplot) (2.0.5)
# Requirement already satisfied: pure-eval in C:\ProgramData\anaconda3\Lib\site-packages (from stack-data->ipython>=8.0->livelossplot) (0.2.2)

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(output_var, input_shape=(dims,)))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\janto\AppData\Roaming\Python\Python311\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(X_train, Y_train, 
          verbose=1, 
          epochs=50, 
          validation_data=(X_test, Y_test),
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    6.902, max:      inf, cur:      inf)
# 	validation       	 (min:    4.521, max:      inf, cur:      inf)
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: inf - val_loss: inf

# %% [markdown]
# ## Red neuronal de una sola capa con early stopping

# %%
# Importación librerías
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(output_var, input_shape=(dims,)))
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=2, verbose=1)

# %%
# Definición de la función ModelCheckpoint para guardar el modelo con mejor desempeño
fBestModel = 'best_model.h5'
best_model = ModelCheckpoint(fBestModel, verbose=0, save_best_only=True)

# %%
# Entrenamiento de la red neuronal con 50 épocas y early stopping
model.fit(X_train, Y_train, 
          verbose=True, 
          epochs=50, 
          batch_size=128,
          validation_data=(X_test,Y_test),
          callbacks=[best_model, early_stop])
# Out:
# Epoch 1/50
#  69/113 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 5.3836
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0024 - val_loss: 0.6318
# Epoch 2/50
#  78/113 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.6898
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6525 - val_loss: 0.5620
# Epoch 3/50
#  81/113 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.6028
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6134 - val_loss: 0.5388
# Epoch 4/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6199 - val_loss: 0.5390
# Epoch 5/50
#  65/113 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.5565
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5929 - val_loss: 0.5186
# Epoch 6/50
#  66/113 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.5599
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5837 - val_loss: 0.5113
# Epoch 7/50
#  85/113 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.5305
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5632 - val_loss: 0.5013
# Epoch 8/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5657 - val_loss: 0.5058
# Epoch 9/50
# 101/113 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.5584
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5544 - val_loss: 0.4966
# Epoch 10/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5549 - val_loss: 0.4979
# Epoch 11/50
#  78/113 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.5281
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5570 - val_loss: 0.4946
# Epoch 12/50
#  75/113 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.5915
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5581 - val_loss: 0.4924
# Epoch 13/50
#  86/113 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.5609
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5507 - val_loss: 0.4906
# Epoch 14/50
#  88/113 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.5591
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5533 - val_loss: 0.4903
# Epoch 15/50
#  75/113 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - loss: 0.5328
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5497 - val_loss: 0.4896
# Epoch 16/50
#  92/113 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - loss: 0.5503
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5479 - val_loss: 0.4895
# Epoch 17/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5450 - val_loss: 0.4911
# Epoch 18/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5428 - val_loss: 0.5043
# Epoch 18: early stopping

# %% [markdown]
# # Red Neuronal Multicapa

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(output_var))
model.add(Activation('relu'))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           257 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,353 (267.00 KB)
#  Trainable params: 68,353 (267.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(X_train, Y_train,
          validation_data = (X_val, Y_val),
          epochs=50, 
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.284, max:    0.778, cur:    0.284)
# 	validation       	 (min:    0.258, max:    0.452, cur:    0.296)
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2839 - val_loss: 0.2959
